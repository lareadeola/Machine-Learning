# %% [markdown]
# <a href="https://colab.research.google.com/github/lareadeola/Machine-Learning/blob/main/Robotics_Practise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
# !pip install modern_robotics

# %%
import modern_robotics as mr

# %%
help(mr.RotInv)
# Out:
# Help on function RotInv in module modern_robotics.core:
#
# RotInv(R)
#     Inverts a rotation matrix
#
#     :param R: A rotation matrix
#     :return: The inverse of R
#
#     Example Input:
#         R = np.array([[0, 0, 1],
#                       [1, 0, 0],
#                       [0, 1, 0]])
#     Output:
#         np.array([[0, 1, 0],
#                   [0, 0, 1],
#                   [1, 0, 0]])

# %%
matrix_a = np.array([[0, 0, 1], [1, 0, 0], [0, 1, 0]])

# %%
mr.RotInv(matrix_a)
# Out:
# array([[0, 1, 0],
#        [0, 0, 1],
#        [1, 0, 0]])
